# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 3.Pandas
# references: https://pandas.pydata.org/docs/reference/

# %% [markdown]
# ## 3.1 Series
#
# Numpy와 유사하나 index를 가지고 있음

# %% [markdown]
# ### 생성
#
# ```python
# series = pd.Series(
#   [90, 85, 80, 75, 70]
#   ) # 인덱스를 지정하지 않으면 0부터 시작
#
# series = pd.Series(
#   [90, 85, 80, 75, 70],
#   index=['국', '영', '수', '사', '과']
#   )
# ```

# %%
series = pd.Series(
  [90, 85, 80, 75, 70]
  )
series
# Out:
# 0    90
# 1    85
# 2    80
# 3    75
# 4    70
# dtype: int64

# %%
series = pd.Series(
  [90, 85, 80, 75, 70],
  index=['국', '영', '수', '사', '과']
  )
series
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    70
# dtype: int64

# %% [markdown]
# ### 추가, 변경, 삭제
# 기존 딕셔너리의 추가, 변경, 삭제와 동일 <br>
# <br>
#
# 추가
# ```python
# series['한국사'] = 100
# ```
# <br>
#
# 변경
# ```python
# series['국'] = 100
# series.국 = 100
# ```
# <br>
#
# 삭제
# ```python
# del series['국']
# ```

# %%
series['한국사'] = 100
series['국'] = 100
del series['수']
series
# Out:
# 국      100
# 영       85
# 사       75
# 과       70
# 한국사    100
# dtype: int64

# %%
series.과 = 80 #기존에 있는 값 변경 가능
series.탐구 = 100 #기존에 없는 값 추가 불가
series
# Out:
# 국      100
# 영       85
# 사       75
# 과       80
# 한국사    100
# dtype: int64

# %% [markdown]
# ### name
# name 속성을 이용하여 series와 index에 이름 부여 가능
#
# ```python
# series.name = '성적'
# series.index.name = '과목'
# ```

# %%
series.name = '성적'
series.index.name = '과목'
series
# Out:
# 과목
# 국      100
# 영       85
# 사       75
# 과       80
# 한국사    100
# Name: 성적, dtype: int64

# %% [markdown]
# ### indexing
#
# ```python
# series[0], series['국']    # 특정 인덱스 번호 혹은 이름 지정
# series.국
#
# series[[0, 2, 1]]         # 인덱스 순서를 원하는 순서대로 변경하여 출력
# series[['국', '수', '영']]  # 인덱스 순서를 원하는 순서대로 변경하여 출력
#
# series[0:3]            # 슬라이싱
# series['국어':'수학']    # 슬라이싱, 끝 점 포함
# ```

# %%
series = pd.Series(
  [90, 85, 80, 75, 70],
  index=['국', '영', '수', '사', '과']
  )
series
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    70
# dtype: int64

# %%
series['국']
series[['국','영']]
series[['국','과','영']]
# Out:
# 국    90
# 과    70
# 영    85
# dtype: int64

# %%
series['국':'사'] #끝값 포함
series[0:3] #끝값 미포함
# Out:
# 국    90
# 영    85
# 수    80
# dtype: int64

# %% [markdown]
# ### series 연산
#
# series끼리 연산 진행 가능 <br>
# 다만, series 연산은 동일 index끼리 연산이므로 index 정보가 다르면 연산 불가 <br>
# <br>
#
# ```python
# series1 = pd.Series(
#   [90, 85, 80, 75, 70],
#   index=['국', '영', '수', '사', '과']
#   )
#
# series2 = pd.Series(
#   [95, 80, 70, 80, 95],
#   index=['국', '영', '수', '사', '과']
#   )
# ```

# %%
series1 = pd.Series(
  [90, 85, 80, 75, 70],
  index=['국', '영', '수', '사', '과']
  )

series2 = pd.Series(
  [95, 80, 70, 80, 95],
  index=['국', '영', '수', '사', '과']
  )

series1 + series2
# Out:
# 국    185
# 영    165
# 수    150
# 사    155
# 과    165
# dtype: int64

# %%
series1 = pd.Series(
  [90, 85, 80, 75, 70],
  index=['국', '영', '수', '사', '탐']
  )

series2 = pd.Series(
  [95, 80, 70, 80, 95],
  index=['국', '영', '수', '사', '과']
  )
series1 + series2 #공통으로 존재하는 index만 계산
# Out:
# 과      NaN
# 국    185.0
# 사    155.0
# 수    150.0
# 영    165.0
# 탐      NaN
# dtype: float64

# %% [markdown]
# ## 3.2 DataFrame
#
# Series가 1d 행렬에 index를 추가한 것과 같이 <br>
# DataFrame은 2d 행렬에 index와 column을 추가한 것 <br>
# 혹은 여러 Series의 합 <br>

# %% [markdown]
# ### 3.2.1 판다스 기초

# %% [markdown]
# #### 생성
#
# 딕셔너리 기반
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
# df
# ```
# <br>
# <br>
#
# 배열 기반
# ```python
# data = [
#   [90, 95, 85],
#   [85, 80, 95],
#   [80, 70, 90],
#   [75, 80, 70],
#   [70, 95, 85]
# ]
#
# index = ['국', '영', '수', '사', '과']
# columns = ['학생1', '학생2', '학생3']
# df = pd.DataFrame(data, index=index, columns=columns)
# ```

# %%
#dictionary 기반 생성
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
pd.DataFrame(data)
df = pd.DataFrame(data, index= index)
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
#배열 기반 생성
data = [
    [90,95,85],
    [85,80,95],
    [80,70,90],
    [75,80,70],
    [70,95,85]]
columns = ['학생1','학생2','학생3']
pd.DataFrame(data)
pd.DataFrame(data, columns = columns)
# Out:
#    학생1  학생2  학생3
# 0   90   95   85
# 1   85   80   95
# 2   80   70   90
# 3   75   80   70
# 4   70   95   85

# %% [markdown]
# #### 추가, 변경, 삭제
# **추가** <br>
# DataFrame의 추가는 기본적으로 열 단위 추가
#
# ```python
# # 현재 row는 국, 영, 수, 사, 과의 5개 정보인데 1개 정보만 추가하게 되면, 이 값을 전체에 복사
# # 즉, 모든 row 값을 90으로 채움
# df['학생4'] = 90
#
# # 만약 2개 이상의 값을 넣고 싶으면 배열을 이용하여 넣어야 함
# # 이 경우 row수와 일치하지 않으면 에러 발생
# df['학생4'] = [90, 80]     # 에러
# df['학생4'] = [90, 80, 70, 60, 50]
# ```
# <br>
#
# **변경** <br>
# 데이터프레임.컬럼.인덱스 = 변경값 <br>
# 기존 컬럼이 존재하면 생성과 유사하게 동작
# ```python
# df.학생3.국 = 100
# df['학생3'] = 100    # df.학생3 = 100
# df['학생3'] = [100, 99, 98, 97, 96]    # df.학생3 = [100, 99, 98, 97, 96]
# ```
#
#
#
# **삭제**
# ```python
# del df['학생4']
# df.drop(columns='학생4')
# ```

# %%
df['재수1'] = 100 #칼럼 추가
# df['재수1'] = [100,90] #에러
df['재수1'] = [100,90,80,70,60] #데이터 개수 맞춰야 함
df
# Out:
#    학생1  학생2  학생3  재수1
# 국   90   95   70  100
# 영   85   80   95   90
# 수   80   70   90   80
# 사   75   80   70   70
# 과   70   95   85   60

# %%
df['재수1'] # =>series로 접근   ##열->행 순서로 접근
df['재수1'] ['사'] =100 #값 바꾸기
df.학생3.국 = 70
df
# Out:
#    학생1  학생2  학생3  재수1
# 국   90   95   70  100
# 영   85   80   95   90
# 수   80   70   90   80
# 사   75   80   70  100
# 과   70   95   85   60

# %%
del df['재수1'] #칼럼삭제
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   70
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
df.drop(columns='학생3')
# Out:
#    학생1  학생2
# 국   90   95
# 영   85   80
# 수   80   70
# 사   75   80
# 과   70   95

# %% [markdown]
# #### name
#
# Series에서와 마찬가지로 이름을 지정할 수 있음 <br>
# 다만, DataFrame은 2차원이므로 index와 column 모두에 이름 지정 가능 <br>
#
# ```python
# df.index.name = '과목'
# df.columns.name = '학생'
# ```

# %%
#행렬에 이름 붙여주기
df.index.name = '과목'
df.columns.name = '학생'
df
# Out:
# 학생  학생1  학생2  학생3
# 과목
# 국    90   95   70
# 영    85   80   95
# 수    80   70   90
# 사    75   80   70
# 과    70   95   85

# %% [markdown]
# #### column 이름 변경
# dataframe의 column 정보는 df.columns에 저장 <br>
# 여기에 저장된 값을 다른 값으로 입력하면 변경 가능 <br>
# 단, 열 전체 정보를 입력해야 함 (열 개수와 입력 값이 일치하지 않으면 에러) <br>
# 개별 column 이름을 변경하고 싶으면 rename 사용
# <br>
#
# ```python
# df.columns
# df.columns = '학생4'    # 에러
# df.columns = ['학생4']  # 에러
# df.rename(columns={'학생1': '학생4'})
# df.columns = ['학생4', '학생5', '학생6']
# ```

# %%
df.columns = ['학생4','학생5','학생6'] #개수를 맞춰야 함
df.columns = '학생4'    # 에러 / 리스트 형태로 넣어야 함
df.columns = ['학생4']  # 에러
# Out:
#     학생4  학생5  학생6
# 과목
# 국    90   95   70
# 영    85   80   95
# 수    80   70   90
# 사    75   80   70
# 과    70   95   85

# %%
df.rename(columns={'학생4':'학생1'}) #학생4 -> 학생1
# Out:
#     학생1  학생5  학생6
# 과목
# 국    90   95   70
# 영    85   80   95
# 수    80   70   90
# 사    75   80   70
# 과    70   95   85

# %% [markdown]
# #### indexing
# **column** <br>
# ```python
# df['학생1']           # Series 반환
# df[['학생1']]         # DataFrame 반환
# df[['학생1', '학생2']] # 다수의 컬럼 선택
# ```
# <br>
#
# **row** <br>
# 항상 슬라이싱(:) 사용
# ```python
# df[:1]
# df[1:3]
# df['국':'수']
# ```

# %%
df[['학생4','학생5']]  #컬럼 단위
df[['학생4','학생5','학생6']] 
df[1:2] #row 단위
# Out:
#     학생4  학생5  학생6
# 과목
# 국    90   95   70
# 영    85   80   95
# 수    80   70   90
# 사    75   80   70
# 과    70   95   85

# %% [markdown]
# ##### iloc, loc
#
# 판다스 데이터프레임에는 위의 인덱싱을 보다 효과적으로 수행할 수 있는 특별한 방법이 존재 <br>
# <br>
#
# > **loc** <br>
# 행 인덱싱은 정수 또는 행 인덱스 데이터, 열 인덱스는 문자열 <br>
# ```python
# dataframe.loc[행 인덱싱]
# dataframe.loc[행 인덱싱, 열 인덱싱]
# ```
#
# <br>
# <br>
#
# > **iloc** <br>
# 사용법은 loc와 큰 차이가 없으나 iloc 내부에는 반드시 정수 인덱싱만 허용 <br>
# ```python
# dataframe.iloc[행 인덱싱]
# dataframe.iloc[행 인덱싱, 열 인덱싱]
# ```

# %%
df.iloc[0:2] #행정보
df.iloc[0:2,1:3]
# Out:
#     학생5  학생6
# 과목
# 국    95   70
# 영    80   95

# %%
df.loc['국':'수','학생4']
# Out:
# 과목
# 국    90
# 영    85
# 수    80
# Name: 학생4, dtype: int64

# %% [markdown]
# #### describe
# 데이터 프레임의 기술통계량 산출 <br>

# %%
df.describe()
# Out:
#              학생4        학생5        학생6
# count   5.000000   5.000000   5.000000
# mean   80.000000  84.000000  82.000000
# std     7.905694  10.839742  11.510864
# min    70.000000  70.000000  70.000000
# 25%    75.000000  80.000000  70.000000
# 50%    80.000000  80.000000  85.000000
# 75%    85.000000  95.000000  90.000000
# max    90.000000  95.000000  95.000000

# %% [markdown]
# #### values
# 데이터 프레임 값을 numpy로 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.values
# ```

# %%
df.values
# Out:
# array([[90, 95, 70],
#        [85, 80, 95],
#        [80, 70, 90],
#        [75, 80, 70],
#        [70, 95, 85]], dtype=int64)

# %% [markdown]
# #### shape
# 데이터 프레임의 행,열을 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.shape
# ```

# %%
df.shape
# Out:
# (5, 3)

# %% [markdown]
# #### unique
# 중복값을 제거한 데이터 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.학생2.unique()
# ```

# %%
df.학생6.unique()
# Out:
# array([70, 95, 90, 85], dtype=int64)

# %% [markdown]
# #### count
# 행별 개수, 열별 개수 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.count()        # 행별 원소 개수
# df.count(axis=1)  # 열별 원소 개수
# ```

# %%
df.count() #null 값은 count 하지 않음
# Out:
# 학생4    5
# 학생5    5
# 학생6    5
# dtype: int64

# %% [markdown]
# #### sort_index
# 인덱스 정렬 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = [3, 1, 4, 2, 5]
# df = pd.DataFrame(data, index=index)
#
# df.sort_index()                   # 오름차순으로 정렬된 데이터 프레임 반환
# df.sort_index(inplace=True)       # 데이터 프레임 자체를 변환
# df.sort_index(ascending=False)    # 내림차순으로 정렬된 데이터 프레임 반환
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = [3, 1, 4, 2, 5]
df = pd.DataFrame(data, index=index)
df

df.sort_index() #default 오름차순
df.sort_index(ascending=False) #index 내림차순
df.sort_index(ascending=True, inplace=True)
df
# Out:
#    학생1  학생2  학생3   재수
# 1   85   80   95  100
# 2   75   80   70   95
# 3   90   95   85   80
# 4   80   70   90   99
# 5   70   95   85   90

# %% [markdown]
# #### sort_values
# 특정 컬럼 값을 기준으로 정렬 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.sort_values(by=['학생1'])                      # 학생1의 점수를 기준으로 오름차순 정렬된 데이터 프레임 반환
# df.sort_values(by=['학생1'], ascending=False)     # 학생1의 점수를 기준으로 내림차순 정렬된 데이터 프레임 반환
# df.sort_values(by=['학생1'], inplace=True)        # 데이터 프레임을 학생1의 점수를 기준으로 오름차순 정렬
# df.sort_values(by=['학생1', '학생2'])              # 학생1, 학생2의 점수를 기준으로 (학생1 우선) 오름차순 정렬된 데이터프레임 반환
# ```

# %%
df.sort_values(by=['학생1'])
df.sort_values(by=['학생1','학생2']) #학생1기준으로 정렬 후 같은 값이 있을때 학생2로 정렬
# Out:
#    학생1  학생2  학생3   재수
# 5   70   95   85   90
# 2   75   80   70   95
# 4   80   70   90   99
# 1   85   80   95  100
# 3   90   95   85   80

# %% [markdown]
# #### apply
# 열 또는 축을 기준으로 함수 적용
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.apply(lambda x: x + 10, axis=1)
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %%
df.학생1.apply(lambda x:pow(x,2))
# Out:
# 국    8100
# 영    7225
# 수    6400
# 사    5625
# 과    4900
# Name: 학생1, dtype: int64

# %%
df.apply(lambda x : pow(x,2),axis=1)
# Out:
#     학생1   학생2   학생3     재수
# 국  8100  9025  7225   6400
# 영  7225  6400  9025  10000
# 수  6400  4900  8100   9801
# 사  5625  6400  4900   9025
# 과  4900  9025  7225   8100

# %% [markdown]
# #### value_counts
# 특정 열을 기준으로 값의 개수 산출
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.value_counts()
# ```

# %%
data = {
    '학생1': [90, 85, 80, 70, 70],
    '학생2': [95, 80, 70, 70, 70],
    '학생3': [85, 95, 70, 70, 70],
    '재수': [80, 100, 99, 70, 70],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   70   99
# 사   70   70   70   70
# 과   70   70   70   70

# %%
df.학생1.value_counts()
# Out:
# 70    2
# 90    1
# 85    1
# 80    1
# Name: 학생1, dtype: int64

# %%
df.value_counts()
# Out:
# 학생1  학생2  학생3  재수
# 70   70   70   70     2
# 80   70   70   99     1
# 85   80   95   100    1
# 90   95   85   80     1
# dtype: int64

# %% [markdown]
# #### set_index
# 특정 열을 index로 설정
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.set_index('학생1')
# ```

# %%
df.set_index('학생1')
# Out:
#      학생2  학생3   재수
# 학생1
# 90    95   85   80
# 85    80   95  100
# 80    70   70   99
# 70    70   70   70
# 70    70   70   70

# %% [markdown]
# ### 3.2.2 데이터 입출력

# %% [markdown]
# #### 입력
# pd.read_csv를 통하여 csv 데이터를 읽음
#
# ```python
# pd.read_csv(파일경로)
# ```
# <br>
#
# read_csv 내에는 다양한 옵션 존재
# - usecols: csv 컬럼에서 특정 컬럼만을 읽음
# - names: 읽어 들인 데이터의 열 이름 변경 가능
# - index_col: 입력하는 파일 내의 특정 column을 index로 설정 가능
# - sep: csv의 데이터 구분은 ",", 하지만 데이터 구분자가 다른 경우 (\t) 이러한 구분자를 sep을 통해 지정할 수 있음
# - skiprows: 읽어들인 데이터 중 필요 없는 row를 제거할 수 있음
# - na_values: 값 중 na_values에 지정한 값은 읽을 때 na 처리

# %%
pd.read_csv(
    r'C:\Users\user\Documents\github\2022_08_06_big_data\bigdata2\dart\market_info.csv',
    #usecols=['종목명','시가총액'], #종목명, 시가총액만 가져오기
    #index_col = ['종목명'], #종목명을 인덱스로 설정
    #skiprows = 2, #row 제거후 불러오기
    #sep='\t', #tab으로 구분된 데이터 불러오기
    na_values=-9.0

)
# Out:
#          종목명       시가총액  외국인비율         거래량     PER     ROE
# 0       삼성전자  3343078.0  49.54  11417477.0    8.49   13.92
# 1   LG에너지솔루션  1195740.0   4.37    445676.0  848.84   10.68
# 2     SK하이닉스   669762.0  50.42   1732651.0    5.84   16.84
# 3   삼성바이오로직스   574374.0  10.53     66133.0  107.33    8.21
# 4       LG화학   464498.0  48.11    178442.0   23.20   18.47
# 5      삼성전자우   426255.0  71.84    789209.0    7.86     NaN
# 6        현대차   423063.0  28.74    400248.0    8.79    6.84
# 7      삼성SDI   422902.0  44.31    255163.0   28.69    8.45
# 8      NAVER   369931.0  53.14    473979.0   36.79  106.72
# 9         기아   324291.0  36.92    795028.0    6.12   14.69
# 10       카카오   300140.0  28.29    976761.0   13.48   17.10
# 11      셀트리온   252017.0  20.79    327687.0   44.78   16.04
# 12      삼성물산   213986.0  16.30    173726.0   13.64    5.40
# 13      KB금융   202813.0  73.61    711370.0    4.38    9.80
# 14  POSCO홀딩스   198742.0  53.94    511338.0    2.83   13.97
# 15     현대모비스   197658.0  35.18    209427.0    8.33    6.87
# 16      신한지주   183630.0  61.76    891173.0    4.44    8.80
# 17   SK이노베이션   171061.0  25.77    203981.0    6.76    1.91
# 18        SK   169060.0  22.37    106894.0    5.12   10.19
# 19      LG전자   150556.0  25.88    667420.0    9.03    6.32
# 20    포스코케미칼   143694.0   7.41    812463.0  104.80     NaN

# %% [markdown]
# #### 출력
# pd.to_csv를 통하여 csv 데이터를 출력
#
# ```python
# pd.to_csv(파일경로)
# ```
# <br>
#
# to_csv 내에는 다양한 옵션 존재
#
# - encoding: encoding을 지정하지 않고 출력 시 excel에서 한글이 깨지는 경우가 존재. 이 경우 utf-8-sig를 사용하면 해결 가능. <br> cp949, euc-kr등의 옵션도 존재
# - sep: 입력 때와 마찬가지로 구분자를 지정해줄 수 있음
# - na_rep: 입력 때와 마찬가지로 특정 값을 na로 처리하여 저장할 수 있음
# - index: index를 출력할지 유무. True, False
# - headers: column을 출력할지 유무. True, False

# %%
df.to_csv('scores.csv',encoding='utf-8-sig',index=False, sep='\t') 
# encoding='utf-8-sig' 한글 깨지는 현상 방지
# index= False : index 제외하고 저장
# sep='\t' : tab으로 저장하기

# %% [markdown]
# ### 3.3.3 데이터 전처리

# %% [markdown]
# #### duplicated
# 데이터프레임 내 중복값 확인

# %%
data = {
    '학생1': [90, 85, 70, 70, 70],
    '학생2': [95, 80, 70, 70, 95],
    '학생3': [85, 95, 70, 70, 85],
    '재수': [80, 100, 70, 70, 90],
}
df = pd.DataFrame(data)
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# #### drop_duplicates

# %%
df.drop_duplicates()
# Out:
#    학생1  학생2  학생3   재수
# 0   90   95   85   80
# 1   85   80   95  100
# 2   70   70   70   70
# 4   70   95   85   90

# %% [markdown]
# #### isna
# 결측값 확인
#
# ```python
# data = {
#     '학생1': [np.NaN, 85, 80, 75, 70],
#     '학생2': [95, 80, np.NaN, 80, 95],
#     '학생3': [85, 95, 90, np.NaN, 85],
#     '재수': [80, np.NaN, 99, 95, 90],
# }
# df = pd.DataFrame(data)
#
# df.isna()
# ```

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)

df.describe()
# Out:
#      학생1    학생2    학생3     재수
# 0   True  False  False  False
# 1  False  False  False   True
# 2  False   True  False  False
# 3  False  False   True  False
# 4  False  False  False  False

# %%
df.isna() #nan 확인
df.isna().sum() #nan 개수
# Out:
# 학생1    1
# 학생2    1
# 학생3    1
# 재수     1
# dtype: int64

# %% [markdown]
# #### fillna
# 결측값을 특정 값으로 대체
#
# ```python
# data = {
#     '학생1': [np.NaN, 85, 80, 75, 70],
#     '학생2': [95, 80, np.NaN, 80, 95],
#     '학생3': [85, 95, 90, np.NaN, 85],
#     '재수': [80, np.NaN, 99, 95, 90],
# }
# df = pd.DataFrame(data)
#
# df.fillna(0)                   # 특정 값으로 대체
# df.fillna(method='ffill')      # 결측값을 앞의 값으로 대체
# df.fillna(method='bfill')      # 결측값을 뒤의 값으로 대체
# ```

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)
df
# Out:
#     학생1   학생2   학생3    재수
# 0   NaN  95.0  85.0  80.0
# 1  85.0  80.0  95.0   NaN
# 2  80.0   NaN  90.0  99.0
# 3  75.0  80.0   NaN  95.0
# 4  70.0  95.0  85.0  90.0

# %%
df.fillna(0)  # nan => 0
df.fillna(method='bfill') #밑에 있는 값으로 채운다
df.fillna(method='ffill') #위에 있는 값으로 채운다
# Out:
#     학생1   학생2   학생3    재수
# 0   NaN  95.0  85.0  80.0
# 1  85.0  80.0  95.0  80.0
# 2  80.0  80.0  90.0  99.0
# 3  75.0  80.0  90.0  95.0
# 4  70.0  95.0  85.0  90.0

# %% [markdown]
# #### dropna
# na가 포함된 값을 drop

# %%
df.dropna()
# Out:
#     학생1   학생2   학생3    재수
# 4  70.0  95.0  85.0  90.0

# %% [markdown]
# ### 3.3.4 데이터 조회

# %% [markdown]
# #### isin
# 주어진 값이 데이터프레임 내에 존재하는지 확인
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.isin([80])
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
df.isin([80, 90]) #80값의 위치 알려줌
# df.isin([80, 90]).sum()
# Out:
#      학생1    학생2    학생3     재수
# 국   True  False  False   True
# 영  False   True  False  False
# 수   True  False   True  False
# 사  False   True  False  False
# 과  False  False  False   True

# %% [markdown]
# #### where
# 특정 조건을 만족하는지 검사 <br>
# 조건을 만족하는 경우 값 변경 가능 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.where(df%2==0, -df)
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.where(df > 70, df+10) #70점 보다 크면 그냥 두고, 70보다 작으면 +10을 해준다
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   80   90   99
# 사   75   80   80   95
# 과   80   95   85   90

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)
df
df.where(df.isna(), df*2)
# Out:
#      학생1    학생2    학생3     재수
# 0    NaN  190.0  170.0  160.0
# 1  170.0  160.0  190.0    NaN
# 2  160.0    NaN  180.0  198.0
# 3  150.0  160.0    NaN  190.0
# 4  140.0  190.0  170.0  180.0

# %% [markdown]
# #### query
# column의 boolean 결과를 쿼리하는 표현 <br>
# 위의 loc를 활용한 방법보다 간단 <br>
# <br>
#
# ```python
# df = pd.DataFrame({
#     'A': range(1, 6),
#     'B': range(10, 0, -2),
#     'C C': range(10, 5, -1)
#     })
#
# df.query('A > B')        # df.loc[df.A > df.B]
# df.query('`C C` < 8')    # df.loc[df['C C'] < 8]
# ```

# %%
data = {
    '학생 1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생 1  학생2  학생3   재수
# 국    90   95   85   80
# 영    85   80   95  100
# 수    80   70   90   99
# 사    75   80   70   95
# 과    70   95   85   90

# %%
df.loc[df.학생1>=80]

# %%
df.query('학생1 >=80 and 학생2>=80')
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100

# %%
#df.query('학생1 in [80,85,90]')
df.query('`학생 1` in [80,85,90]') #변수에 띄어쓰기가 있을때 ``로 묶어줌
# Out:
#    학생 1  학생2  학생3   재수
# 국    90   95   85   80
# 영    85   80   95  100
# 수    80   70   90   99

# %% [markdown]
# ### 3.3.5 컬럼 조작

# %% [markdown]
# #### filter
# 특정 조건에 맞는 열이나 행을 추출
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.filter(items=['학생1', '학생2'])    # 주어진 열을 선택
# df.filter(like='학생',  axis=1)       # 학생이라는 단어를 포함하는 열 선택
# df.filter(regex='\d', axis=1)        # 숫자를 포함하는 열 선택
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %%
df.filter(items=['학생2','학생3']) #items = 컬럼명
# Out:
#    학생2  학생3
# 국   95   85
# 영   80   95
# 수   70   90
# 사   80   70
# 과   95   85

# %%
#특정 단어 검색
df.filter(like='학생',  axis=1)
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
#정규표현식
df.filter(regex='\d',  axis=1) #\d = 숫자가 존재하는 컬럼명 필터
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %% [markdown]
# #### drop
# column이나 row를 제거
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.drop(columns='학생1')               # 1개 컬럼 drop
# df.drop(columns=['학생1', '학생2'])     # 복수개 컬럼 drop
#
# df.drop('국')             # 1개 row drop
# df.drop(['국', '영'])      # 복수개 row drop
# ```

# %%
df.drop('국') #row 단위
df.drop(columns = ['학생1','학생2'])
# Out:
#    학생3   재수
# 국   85   80
# 영   95  100
# 수   90   99
# 사   70   95
# 과   85   90

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %%
df.query('재수>=90').filter(like='학생',axis=1)
# Out:
#    학생1  학생2  학생3
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %% [markdown]
# ### 3.3.6 통계

# %% [markdown]
# #### sum
# 데이터프레임의 행 또는 열 기준 합을 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.sum()         # default 0: 학생별 합
# df.sum(axis=1)   # 1: 과목별 합
# ```

# %%
df.sum()
df.sum(axis=1)
# Out:
# 국    350
# 영    360
# 수    339
# 사    320
# 과    340
# dtype: int64

# %% [markdown]
# #### mean
# 데이터프레임의 행 또는 열 기준 평균 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.mean()         # default 0: 학생별 평균
# df.mean(axis=1)   # 1: 과목별 평균
# ```

# %%
df.mean()
# Out:
# 학생1    80.0
# 학생2    84.0
# 학생3    85.0
# 재수     92.8
# dtype: float64

# %% [markdown]
# #### median
# 데이터프레임의 행 또는 열 기준 중앙값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.median()         # default 0: 학생별 중앙값
# df.median(axis=1)   # 1: 과목별 중앙값
# ```

# %%
df.median()
# Out:
# 학생1    80.0
# 학생2    80.0
# 학생3    85.0
# 재수     95.0
# dtype: float64

# %% [markdown]
# #### mode
# 데이터프레임의 행 또는 열 기준 최빈값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.mode()         # default 0: 학생별 합
# df.mode(axis=1)   # 1: 과목별 합
# ```

# %%
df.mode() #학생3에서 85값이 가장 많음/ 학생1은 값이 모두 하나씩 존재
# Out:
#    학생1   학생2   학생3   재수
# 0   70  80.0  85.0   80
# 1   75  95.0   NaN   90
# 2   80   NaN   NaN   95
# 3   85   NaN   NaN   99
# 4   90   NaN   NaN  100

# %% [markdown]
# #### max
# 데이터프레임의 행 또는 열 기준 최댓값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.max()         # default 0: 학생별 최댓값
# df.max(axis=1)   # 1: 과목별 최댓값
# ```

# %%
df.max()
# Out:
# 학생1     90
# 학생2     95
# 학생3     95
# 재수     100
# dtype: int64

# %% [markdown]
# #### min
# 데이터프레임의 행 또는 열 기준 최솟값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.min()         # default 0: 학생별 최솟값
# df.min(axis=1)   # 1: 과목별 최솟값
# ```

# %%
df.min()
# Out:
# 학생1    70
# 학생2    70
# 학생3    70
# 재수     80
# dtype: int64

# %% [markdown]
# #### cumsum
#
# 데이터프레임의 행 또는 열 기준 누적합 반환
#
# ```python
# data = {
#     '자산1': [0.01, 0.02, 0.03],
#     '자산2': [0.06, 0.09, 0.07],
#     '자산3': [0.04, 0.09, 0.01],
# }
# index = [2018, 2019, 2020]
# df = pd.DataFrame(data, index=index)
#
# df.cumsum()         # default 0: 자산별 누적합
# df.cumsum(axis=1)   # 1: 연도별 누적합
# ```

# %%
df.cumsum()
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영  175  175  180  180
# 수  255  245  270  279
# 사  330  325  340  374
# 과  400  420  425  464

# %% [markdown]
# #### cumprod
# 데이터프레임의 행 또는 열 기준 누적곱 반환
#
# ```python
# data = {
#     '자산1': [0.01, 0.02, 0.03],
#     '자산2': [0.06, 0.09, 0.07],
#     '자산3': [0.04, 0.09, 0.01],
# }
# index = [2018, 2019, 2020]
# df = pd.DataFrame(data, index=index)
#
# df.cumprod()         # default 0: 자산별 누적곱
# df.cumprod(axis=1)   # 1: 연도별 누적곱
# ```

# %%
df.cumprod()
# Out:
#           학생1         학생2         학생3          재수
# 국          90          95          85          80
# 영        7650        7600        8075        8000
# 수      612000      532000      726750      792000
# 사    45900000    42560000    50872500    75240000
# 과  3213000000  4043200000  4324162500  6771600000

# %% [markdown]
# #### rank
# 데이터프레임의 행 또는 열 기준 순위 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.rank()         # default 0: 학생별 최솟값
# df.rank(axis=1)   # 1: 과목별 최솟값
# ```

# %%
df.rank() #가장 작은 값 = 1 / 2,3등이 같은 값이면 2.5등 배정
# Out:
#    학생1  학생2  학생3   재수
# 국  5.0  4.5  2.5  1.0
# 영  4.0  2.5  5.0  5.0
# 수  3.0  1.0  4.0  4.0
# 사  2.0  2.5  1.0  3.0
# 과  1.0  4.5  2.5  2.0

# %% [markdown]
# #### quantile
# 데이터프레임의 행 또는 열 기준 분위수 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.quantile()         # default 0: 학생별 중앙값
# df.quantile(q=0.8)    # default 0: 학생별 80%값 반환
# df.quantile(axis=1)   # 1: 과목별 학생별 중앙값
# ```

# %%
df.quantile()
df.quantile(q=0.1)
df.quantile(q=0.8)
# Out:
# 학생1    86.0
# 학생2    95.0
# 학생3    91.0
# 재수     99.2
# Name: 0.8, dtype: float64

# %% [markdown]
# #### var
# 데이터프레임의 행 또는 열 기준 분산 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.var()         # default 0: 학생별 분산
# df.var(axis=1)   # 1: 과목별 분산
# ```

# %%
df.var()
# Out:
# 학생1     62.5
# 학생2    117.5
# 학생3     87.5
# 재수      66.7
# dtype: float64

# %% [markdown]
# #### std
# 데이터프레임의 행 또는 열 기준 표준편차 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.std()         # default 0: 학생별 표준편차
# df.std(axis=1)   # 1: 과목별 표준편차
# ```

# %%
df.std()
# Out:
# 학생1     7.905694
# 학생2    10.839742
# 학생3     9.354143
# 재수      8.167007
# dtype: float64

# %% [markdown]
# #### corr
# 데이터프레임 내 상관관계 행렬 반환 <br>
# 상관관계는 pearson, kendall, spearman 방법 가능
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.corr()                     # pearson
# df.corr(method='kendall')     # kendall
# df.corr(method='spearman')    # spearman
# ```

# %%
df.corr()
# Out:
#               학생1           학생2       학생3        재수
# 학생1  1.000000e+00  8.291465e-17  0.422577 -0.290401
# 학생2  8.291465e-17  1.000000e+00 -0.123278 -0.835891
# 학생3  4.225771e-01 -1.232784e-01  1.000000  0.229072
# 재수  -2.904012e-01 -8.358914e-01  0.229072  1.000000

# %% [markdown]
# #### cov
# 데이터프레임 내 공분산 행렬 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.cov()
# ```

# %%
df.cov()
# Out:
#        학생1    학생2    학생3     재수
# 학생1  62.50    0.0  31.25 -18.75
# 학생2   0.00  117.5 -12.50 -74.00
# 학생3  31.25  -12.5  87.50  17.50
# 재수  -18.75  -74.0  17.50  66.70

# %% [markdown]
# ### 3.3.7 집계

# %% [markdown]
# #### groupby
# 그룹별 집계
#
# ```python
# data = {
#     '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
#     '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
# }
# df = pd.DataFrame(data)
#
# df.groupby('구분').mean()
# ```

# %%
data = {
    '과목' :['국','영','수','사','과'] *5,
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
}
df = pd.DataFrame(data)
df
df.groupby(['구분','과목']).mean()
df.groupby(['과목','구분']).mean()
# Out:
#               점수
# 과목 구분
# 과  재수  85.000000
#    현역  83.333333
# 국  재수  90.000000
#    현역  90.000000
# 사  재수  97.500000
#    현역  75.000000
# 수  재수  92.500000
#    현역  80.000000
# 영  재수  95.000000
#    현역  86.666667

# %% [markdown]
# #### agg
# 다양한 집계함수 사용 가능
#
# ```python
# data = {
#     '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
#     '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
# }
# df = pd.DataFrame(data)
#
# df.groupby('구분').agg(['min', 'max', 'mean'])
# ```

# %%
data = {
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
}
df = pd.DataFrame(data)
df
df.groupby('구분').agg(['min','max','mean'])
# Out:
#     점수
#    min  max  mean
# 구분
# 재수  85  100  92.0
# 현역  70   95  83.0

# %% [markdown]
# ### 3.3.8 결합

# %% [markdown]
# #### merge
# 두 데이터프레임 병합 <br>
#
# on: 결합 대상 key 컬럼 <br>
# how <br>
# - left: 왼쪽 데이터 프레임의 키를 중심으로 결합
# - right: 오른쪽 데이터 프레임의 키를 중심으로 결합
# - outer: 두 데이터 프레임의 키를 중심으로 결합
# - inner: 두 데이터 프레임에서 공통으로 존재하는 값만 결합
# - cross: 모든 경우의 수를 구하여 결합
#
# ```python
# df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
# df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})
#
# df1.merge(df2, how='inner', on='a')  #결합하는 key 이름이 같을때
# df1.merge(df2, how='left', on='a')
# df1.merge(df2, how='cross')
#
#
# df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'], #결합하는 key 이름이 다를때
#                     'value': [1, 2, 3, 5]})
# df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
#                     'value': [5, 6, 7, 8]})
#
# df1.merge(df2, left_on='lkey', right_on='rkey')
# df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=('_left', '_right'))
# ```

# %%
df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})

# %%
df1.merge(df2, how='inner', on='a') #두개 모두 존재하지 않으면 버림/ default=inner
df1.merge(df2, how='left', on='a') 
df1.merge(df2, how='right', on='a') 
df1.merge(df2, how='cross', on='a') #모든 경우의 수
# Out:
#      a    b  c
# 0  foo  1.0  3
# 1  baz  NaN  4

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'], #결합하는 key 이름이 다를때
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %% [markdown]
# #### concat
# 두 데이터프레임 결합 <br>
# 리스트 내의 데이터프레임 결합에도 사용 <br>
#
# ```python
# df1 = pd.DataFrame([['a', 1], ['b', 2]],
#                    columns=['letter', 'number'])
# df2 = pd.DataFrame([['c', 3], ['d', 4]],
#                    columns=['letter', 'number'])
#
# pd.concat([df1, df2])            # 아래로 결합
# pd.concat([df1, df2], axis=1)    # 옆으로 결합
#
#
# dataframe_list = [df1, df2]
# pd.concat(dataframe_list)
# ```

# %%
pd.concat([df1,df2],axis=1)
# Out:
#      a  b    a  c
# 0  foo  1  foo  3
# 1  bar  2  baz  4

# %%
x = pd.DataFrame({
   'x': np.arange(30)})

# %%
np.array_split(x,3) #리스트 자르기
pd.concat(np.array_split(x,3)) # 잘린 리스트 다시 붙이기

# %% [markdown]
# ### 3.3.9 데이터프레임 조작

# %% [markdown]
# #### explode
# 리스트 내의 값을 row로 분해
#
# ```python
# data = {
#     '학생1': [[90, 85, 80, 75, 70]],
#     '학생2': [[95, 80, 70, 80, 95]],
#     '학생3': [[85, 95, 90, 70, 85]],
# }
# df = pd.DataFrame(data)
#
# df.explode('학생1')
# df.explode('학생2')
# df.explode('학생3')
# ```

# %%
data = {
    '학생1': [[90, 85, 80, 75, 70]],
    '학생2': [[95, 80, 70, 80, 95]],
    '학생3': [[85, 95, 90, 70, 85]],
}
df = pd.DataFrame(data)
df
# Out:
#                     학생1                   학생2                   학생3
# 0  [90, 85, 80, 75, 70]  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]

# %%
df.explode('학생1') #리스트 값을 row로 풀어줌
df.explode('학생2') #두번 하면 값이 중복되어서 풀어짐/ 한번에 한번만 쓸것
# Out:
#                     학생1                   학생2                   학생3
# 0  [90, 85, 80, 75, 70]  [95, 80, 70, 80, 95]  [85, 95, 90, 70, 85]

# %% [markdown]
# #### pivot
# 인덱스, 컬럼 값으로 데이터 재정렬
#
# ```python
# df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
#                            'two'],
#                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
#                    'baz': [1, 2, 3, 4, 5, 6],
#                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
#
# df.pivot(index='foo', columns='bar', values='baz')
# df.pivot(index='foo', columns='bar')['baz']
# df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
# ```

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index='foo', columns='bar')
df.pivot(index='foo', columns='bar', values=['baz','zoo'])
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %% [markdown]
# #### melt
# uppivot, 데이터 프레임 재정렬
#
# ```python
# data = {
#   'A': {0: 'a', 1: 'b', 2: 'c'},
#   'B': {0: 1, 1: 3, 2: 5},
#   'C': {0: 2, 1: 4, 2: 6}
#   }
# df = pd.DataFrame(data)
#
#
# df.melt(id_vars=['A'], value_vars=['B'])
# df.melt(id_vars=['A'], value_vars=['B', 'C'])
# df.melt(id_vars=['A'], value_vars=['B', 'C'], var_name='new_var_name', value_name='new_value_name')
# ```

# %%
data = {
  'A': {0: 'a', 1: 'b', 2: 'c'},
  'B': {0: 1, 1: 3, 2: 5},
  'C': {0: 2, 1: 4, 2: 6}
  }
df = pd.DataFrame(data)
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
df.melt(id_vars=['A'], value_vars=['B'])
df.melt(id_vars=['A'], value_vars=['B'], var_name='var', value_name='val')
# Out:
#    A var  val
# 0  a   B    1
# 1  b   B    3
# 2  c   B    5

# %% [markdown]
# #### stack
# 데이터를 아래로 이어붙임
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.stack()
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
df.stack()
# Out:
# 국  학생1    90
#    학생2    95
#    학생3    85
# 영  학생1    85
#    학생2    80
#    학생3    95
# 수  학생1    80
#    학생2    70
#    학생3    90
# 사  학생1    75
#    학생2    80
#    학생3    70
# 과  학생1    70
#    학생2    95
#    학생3    85
# dtype: int64

# %% [markdown]
# #### unstack
#
# 멀티 인덱스 데이터프레임을 컬럼으로 분할
#
#
# ```python
# scores = [90, 95, 85, 85, 80, 95, 80, 70, 90, 75, 80, 70, 70, 95, 85]
# index = pd.MultiIndex.from_tuples(
#     [('국', '학생1'),
#      ('국', '학생2'),
#      ('국', '학생3'),
#      ('영', '학생1'),
#      ('영', '학생2'),
#      ('영', '학생3'),
#      ('수', '학생1'),
#      ('수', '학생2'),
#      ('수', '학생3'),
#      ('사', '학생1'),
#      ('사', '학생2'),
#      ('사', '학생3'),
#      ('과', '학생1'),
#      ('과', '학생2'),
#      ('과', '학생3')],
# )
# df = pd.Series(scores, index=index)
#
# df.unstack()
# ```

# %%
scores = [90, 95, 85, 85, 80, 95, 80, 70, 90, 75, 80, 70, 70, 95, 85]
index = pd.MultiIndex.from_tuples(
    [('국', '학생1'),
     ('국', '학생2'),
     ('국', '학생3'),
     ('영', '학생1'),
     ('영', '학생2'),
     ('영', '학생3'),
     ('수', '학생1'),
     ('수', '학생2'),
     ('수', '학생3'),
     ('사', '학생1'),
     ('사', '학생2'),
     ('사', '학생3'),
     ('과', '학생1'),
     ('과', '학생2'),
     ('과', '학생3')],
)
df = pd.Series(scores, index=index)
df
# Out:
# 국  학생1    90
#    학생2    95
#    학생3    85
# 영  학생1    85
#    학생2    80
#    학생3    95
# 수  학생1    80
#    학생2    70
#    학생3    90
# 사  학생1    75
#    학생2    80
#    학생3    70
# 과  학생1    70
#    학생2    95
#    학생3    85
# dtype: int64

# %%
df.unstack()
# Out:
#    학생1  학생2  학생3
# 과   70   95   85
# 국   90   95   85
# 사   75   80   70
# 수   80   70   90
# 영   85   80   95

# %% [markdown]
# ## 3.3. 시계열 데이터

# %% [markdown]
# #### date_range
# 주어진 범위에 해당하는 date 리스트 반환
#
# ```python
# pd.date_range(start='9/1/2022', end='9/30/2022')
# pd.date_range(start='2022-09-01', end='2022-09-30')
# pd.date_range(start='2022-09-01', end='2022-09-30', freq='1W')    # 1주 단위로 date 생성
# pd.date_range(start='2022-09-01', periods=8)                      # 시작일 기준 8개의 날 생성
# pd.date_range(end='2022-09-01', periods=8)                        # 종료일 기준 8개의 날 생성
# ```

# %% [markdown]
# #### shift
#
# 데이터 프레임의 인덱스 또는 컬럼을 주어진 숫자 만큼 옮김
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.shift(periods=1)                 # 아래로 한 칸 이동
# df.shift(periods=1, axis='columns') # 컬럼 한 칸 이동
# df.shift(periods=3, fill_value=0)   # 아래로 세 칸 이동 후 nan값을 0으로 채움
# df.shift(periods=3, freq='D')       # 3일 이동
# ```

# %% [markdown]
# #### diff
# 주어진 숫자 만큼의 인덱스 혹은 컬럼 차를 계산
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.diff()
# df.diff(periods=3)     # 3칸 간격의 차를 계산
# ```

# %% [markdown]
# #### pct_change
# 주어진 숫자 만큼의 인덱스 혹은 컬럼 변화율 계산
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.pct_change()
# df.pct_change(periods=3)     # 3칸 간격의 변화율 계산
# ```

# %% [markdown]
# #### rolling
# 주어진 숫자 만큼의 윈도우 생성 <br>
# 생성된 윈도우 내에서 집계 함수 사용 가능 <br>
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.rolling(2).sum()
# ```

# %% [markdown]
# ## 3.4 시각화
# 데이터프레임 값을 시각화
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2020-01-01", "2020-01-05"))
#
# df.plot()                            # 모든 컬럼에 대한 line 그래프
# df.plot(legend=False)                # 범주를 출력하지 않음
# df.plot(kind='box')                  # 열 별 box plot
# df.plot(kind='density')              # 열 별 밀도함수
# df.plot(kind='pie', subplots=True)   # pie 그래프
# ```
