# %% [markdown]
# # 6\. Visualization

# %% [markdown]
# ## 6.1 matplotlib
#
# reference: https://matplotlib.org/stable/plot_types/index.html

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Scatter Plots
# 데이터가 어떻게 분포하고 있는지 확인할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make the data
# x = 4 + np.random.normal(0, 2, 24)
# y = 4 + np.random.normal(0, 2, len(x))
#
# # size and color:
# sizes = np.random.uniform(15, 80, len(x))
# colors = np.random.uniform(15, 80, len(x))
#
# # plot
# fig, ax = plt.subplots()
# ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
x = np.random.normal(0, 2, 24)
y = np.random.normal(0, 2, len(x))

sizes = np.random.uniform(15,80,len(x))
colors = np.random.uniform(15,80,len(x))

plt.scatter(x, y, s = sizes, c = colors)

# %% [markdown]
# #### Bar Charts
# 범주별 빈도를 확인할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data:
# x = 0.5 + np.arange(8)
# y = np.random.uniform(2, 7, len(x))
#
# # plot
# fig, ax = plt.subplots()
#
# ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# #### Line Chart
# 시간의 흐름에 따른 변화를 보고자할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data
# x = np.linspace(0, 10, 100)
# y = 4 + 2 * np.sin(2 * x)
#
# # plot
# fig, ax = plt.subplots()
#
# ax.plot(x, y, linewidth=2.0)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

plt.plot(x,y)

# %% [markdown]
# #### Box Plots
# 변수의 이상치 및 특징을 파악하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# plt.style.use('_mpl-gallery')
#
# # make data:
# data = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))
#
# # plot
# fig, ax = plt.subplots()
# box_plot = ax.boxplot(
#   data,
#   positions=[2, 4, 6],
#   widths=1.5, patch_artist=True,
#   showmeans=False, showfliers=False,
#   medianprops={"color": "white", "linewidth": 0.5},
#   boxprops={
#     "facecolor": "C0", "edgecolor": "white", "linewidth": 0.5},
#   whiskerprops={"color": "C0", "linewidth": 1.5},
#   capprops={"color": "C0", "linewidth": 1.5}
#   )
#
# plt.show()
# ```

# %%
data = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))
data.shape
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x272bb1a64c0>,
#   <matplotlib.lines.Line2D at 0x272bb1a6790>,
#   <matplotlib.lines.Line2D at 0x272bb1af8e0>,
#   <matplotlib.lines.Line2D at 0x272bb1afc10>,
#   <matplotlib.lines.Line2D at 0x272bb2223a0>,
#   <matplotlib.lines.Line2D at 0x272bb222670>],
#  'caps': [<matplotlib.lines.Line2D at 0x272bb1a6a60>,
#   <matplotlib.lines.Line2D at 0x272bb1a6d30>,
#   <matplotlib.lines.Line2D at 0x272bb1afee0>,
#   <matplotlib.lines.Line2D at 0x272bb1bf040>,
#   <matplotlib.lines.Line2D at 0x272bb222940>,
#   <matplotlib.lines.Line2D at 0x272bb222c10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x272ba1a56a0>,
#   <matplotlib.lines.Line2D at 0x272bb1af5e0>,
#   <matplotlib.lines.Line2D at 0x272bb1bf8b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x272bb1af040>,
#   <matplotlib.lines.Line2D at 0x272bb1bf310>,
#   <matplotlib.lines.Line2D at 0x272bb222ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x272bb1af310>,
#   <matplotlib.lines.Line2D at 0x272bb1bf5e0>,
#   <matplotlib.lines.Line2D at 0x272bb23e1f0>],
#  'means': []}

# %% [markdown]
# #### Pie Charts
# 카테고리별 비율을 시각화하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
#
# # Pie chart, where the slices will be ordered and plotted counter-clockwise:
# labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
# sizes = [15, 30, 45, 10]
# explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice
#
# fig1, ax1 = plt.subplots()
# ax1.pie(
#   sizes,
#   explode=explode,
#   labels=labels,
#   autopct='%1.1f%%',
#   shadow=True,
#   startangle=90
#   )
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#
# plt.show()
# ```

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
counts = [10, 30, 45, 15]
explode = (0, 0.1, 0, 0)

plt.pie(counts, labels=labels, explode=explode, startangle = 90, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x272bbfbe430>,
#   <matplotlib.patches.Wedge at 0x272bbfbeb50>,
#   <matplotlib.patches.Wedge at 0x272bbfcc2b0>,
#   <matplotlib.patches.Wedge at 0x272bbfcc9d0>],
#  [Text(-0.3399186987098806, 1.0461621663333949, 'Frogs'),
#   Text(-1.1999999999999986, -5.617605406142127e-08, 'Hogs'),
#   Text(0.7778174957174648, -0.7778174228929382, 'Dogs'),
#   Text(0.4993895221842247, 0.9801071906340714, 'Logs')],
#  [Text(-0.18541019929629848, 0.5706339089091244, '10.0%'),
#   Text(-0.6999999999999992, -3.27693648691624e-08, '30.0%'),
#   Text(0.4242640885731626, -0.4242640488506935, '45.0%'),
#   Text(0.2723942848277589, 0.5346039221640388, '15.0%')])

# %% [markdown]
# #### Histograms
# 데이터의 분포를 확인하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data
# x = 4 + np.random.normal(0, 1.5, 200)
#
# # plot:
# fig, ax = plt.subplots()
#
# ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 56), yticks=np.linspace(0, 56, 9))
#
# plt.show()
# ```

# %%
x = 4 + np.random.normal(0, 1.5, 200)
plt.hist(x, bins=12, edgecolor='black')
# Out:
# (array([ 3.,  2.,  4., 16., 33., 31., 35., 41., 22.,  7.,  4.,  2.]),
#  array([-0.86568137, -0.094608  ,  0.67646537,  1.44753874,  2.21861211,
#          2.98968548,  3.76075885,  4.53183222,  5.30290559,  6.07397896,
#          6.84505233,  7.6161257 ,  8.38719907]),
#  <BarContainer object of 12 artists>)

# %% [markdown]
# ## 6.2 seaborn
#
# reference: https://seaborn.pydata.org

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# %% [markdown]
# ### Scatter Plots
# x가 continous한 값이라면 산점도 <br>
# x가 categorical 값이라면 jitter <br>
# <br>
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - style: 카테고리별 다른 그림으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
#
# sns.relplot(
#     data=tips,
#     x="total_bill", y="tip", hue="smoker", style="time",
# )
# ```

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
    hue = 'smoker',
    style = 'time',
    col = 'sex',
    row = 'day'
)

# %%
sns.relplot(
    data=tips,
    x='sex',
    y='tip',
    hue = 'smoker',
    style = 'time'
)

# %% [markdown]
# ### Bar Charts
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - x: x를 쓰면 일반적인 수직 그래프
#   - y: y를 쓰면 수평 그래프
#   - kind='count': 빈도 계산
#   - palette='pastel': 다양한 색상을 입힘
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# titanic = sns.load_dataset("titanic")
#
# sns.catplot(
#     data=titanic,
#     x="deck", hue="class", kind="count",
#     palette="pastel",
# )
# ```

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
sns.catplot(
    data=titanic,
    x='deck',
    kind= 'count',
    hue= 'class',
    palette='Greens_r'
)

# %% [markdown]
# ### Line Charts
#
# >
# x가 continous한 값이라면 일반적 시계열 모양 <br>
# x가 중복된 값을 가지고 있으면 95% 신뢰구간을 표현 <br>
# <br>
# args
#   - errorbar
#     - None: 신뢰구간 제거
#     - sd: 표준편차 신뢰구간
#   - hue: 그룹 별 다른 색상으로 plot
#   - style: 카테고리별 다른 그림으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# dowjones = sns.load_dataset("dowjones")
# sns.relplot(data=dowjones, x="Date", y="Price", kind="line")
#
# fmri = sns.load_dataset("fmri")
# sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")
# ```

# %%
dowjones = sns.load_dataset("dowjones")
dowjones
# Out:
#            Date   Price
# 0    1914-12-01   55.00
# 1    1915-01-01   56.55
# 2    1915-02-01   56.00
# 3    1915-03-01   58.30
# 4    1915-04-01   66.45
# ..          ...     ...
# 644  1968-08-01  883.72
# 645  1968-09-01  922.80
# 646  1968-10-01  955.47
# 647  1968-11-01  964.12
# 648  1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
sns.relplot(
    data= dowjones,
    x='Date',
    y='Price',
    kind='line'
)

# %%
fmri = sns.load_dataset('fmri')
fmri.query('timepoint==10')
# Out:
#      subject  timepoint event    region    signal
# 113      s13         10  stim  parietal -0.074503
# 114      s12         10  stim  parietal -0.066970
# 115      s11         10  stim  parietal -0.072780
# 116      s10         10  stim  parietal -0.041702
# 117       s9         10  stim  parietal -0.032380
# 118       s8         10  stim  parietal  0.065198
# 119       s7         10  stim  parietal  0.001648
# 120       s6         10  stim  parietal -0.075433
# 121       s5         10  stim  parietal -0.114762
# 122       s4         10  stim  parietal -0.152652
# 123       s3         10  stim  parietal  0.089231
# 124       s2         10  stim  parietal -0.087688
# 125       s1         10  stim  parietal -0.133041
# 126       s0         10  stim  parietal -0.047915
# 402      s12         10  stim   frontal -0.043594
# 405       s0         10  stim   frontal -0.060433
# 406       s1         10  stim   frontal -0.143302
# 407       s2         10  stim   frontal -0.075936
# 408       s3         10  stim   frontal  0.012525
# 409       s4         10  stim   frontal -0.132442
# 410       s5         10  stim   frontal -0.118451
# 411       s6         10  stim   frontal -0.075961
# 412       s7         10  stim   frontal -0.024942
# 413       s8         10  stim   frontal -0.008700
# 414       s9         10  stim   frontal -0.101178
# 415      s10         10  stim   frontal -0.015356
# 416      s11         10  stim   frontal -0.159772
# 417      s13         10  stim   frontal -0.110285
# 898      s12         10   cue  parietal -0.017928
# 900       s9         10   cue  parietal -0.013538
# 911      s13         10   cue  parietal -0.073328
# 913      s11         10   cue  parietal -0.042917
# 915      s10         10   cue  parietal -0.056047
# 916       s8         10   cue  parietal -0.045906
# 917       s7         10   cue  parietal -0.014283
# 918       s6         10   cue  parietal -0.063755
# 919       s5         10   cue  parietal -0.049765
# 920       s4         10   cue  parietal -0.068971
# 921       s3         10   cue  parietal -0.091749
# 922       s2         10   cue  parietal -0.022062
# 923       s1         10   cue  parietal -0.176453
# 924       s0         10   cue  parietal -0.032699
# 952      s13         10   cue   frontal -0.066287
# 953      s12         10   cue   frontal -0.009354
# 955      s11         10   cue   frontal -0.004138
# 1005      s9         10   cue   frontal  0.010463
# 1008      s7         10   cue   frontal  0.005585
# 1009      s6         10   cue   frontal -0.064226
# 1010      s5         10   cue   frontal -0.025539
# 1011      s4         10   cue   frontal -0.066593
# 1012      s3         10   cue   frontal -0.093257
# 1013      s2         10   cue   frontal -0.003771
# 1014      s1         10   cue   frontal -0.097984
# 1015      s0         10   cue   frontal  0.010984
# 1047     s10         10   cue   frontal -0.016124
# 1048      s8         10   cue   frontal -0.015141

# %%
sns.relplot(
    data= fmri,
    x='timepoint',
    y='signal',
    kind='line'
)
#95% 수준 범위로 표현

# %% [markdown]
# ### Box Plots
# >
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
# sns.catplot(data=tips, x="day", y="total_bill")                           # 점도표
# sns.catplot(data=tips, x="day", y="total_bill", kind="box")               # boxplot
# sns.catplot(
#   data=tips, x="total_bill", y="day", hue="sex",
#   kind="violin", split=True
#   ) # violin
# ```

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='box',
    hue= 'sex',
    col='time'
)

# %% [markdown]
# ### Histograms
# >
# args
#   - binwidth: 구간 범위 설정
#   - hue: 그룹 별 다른 색상으로 plot
#   - multiple: 다른 그룹을 어떻게 표현할지 설정
#     - stack: 합하여 출력
#     - dodge: 분리하여 출력
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - stat: 어떤 통계지표로 출력할지 출력
#     - density: 밀도 출력
#     - probability: 확률 출력
#
# ```python
# penguins = sns.load_dataset("penguins")
# sns.displot(penguins, x="flipper_length_mm", binwidth=3, hue='species', multiple='dodge', stats='density')
# ```

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    binwidth=3,    #170-173
    hue='species',
    stat= 'density',
    multiple = 'dodge' #데이터 분리 'stack'->데이터 쌓음
)

# %% [markdown]
# ### Distplots
# >args
#   - kind: 어떤 타입을 출력할지 설정
#     - kde: 커널 분포 출력
#     - ecdf: 누적 분포 출력
#   - hue: 그룹 별 다른 색상으로 plot
#   - multiple: 다른 그룹을 어떻게 표현할지 설정
#     - stack: 합하여 출력
#     - dodge: 분리하여 출력
#   - fill: bool: 면적을 채울지 설정
#
# ```python
# sns.displot(penguins, x="flipper_length_mm", kind="kde")
# ```
# <br>
#
#
# **joint plot**
# ```python
# sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
#
# sns.jointplot(
#     data=penguins,
#     x="bill_length_mm", y="bill_depth_mm", hue="species",
#     kind="kde"
# )
#
# ```

# %%
sns.displot(
    data = penguins,
    x='flipper_length_mm',
    kind = 'kde'
)

# %%
sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm'
)

# %%
sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    hue='species',
    kind='kde'
)

# %% [markdown]
# ### Heatmaps
# >
# args
# - cmap: colormap 설정
#   - Blues
#   - Reds
#   - YlGnBu
#
# ```python
# normal_data = np.random.randn(10, 12)
# ax = sns.heatmap(normal_data)
# ```

# %%
normal_data = np.random.randn(10, 12)
ax = sns.heatmap(
    normal_data,
    cmap='cubehelix')

# %% [markdown]
# ### Model
# >
# args
# - y_jitter: y값의 출력 옵션 설정
# - hue: 그룹 별 다른 색상으로 plot
# - markers: 어떤 모양으로 표현할지 설정
# - logistic: bool
#   - True: logistic regression plot
# - lowess
#   - True: nonparametric regression by lowess
# - col: 해당 컬럼의 값을 기준으로 분할하여 plot
# - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
# sns.lmplot(x="total_bill", y="tip", data=tips)
#
# tips["big_tip"] = (tips.tip / tips.total_bill) > .15
# sns.lmplot(x="total_bill", y="big_tip", data=tips, y_jitter=.03, logistic=True)
# ```
# <br>
#
# **joint plot**
# ```python
# sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");
# ```
#
# **pair plot**
# ```python
# sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
#              hue="smoker", height=5, kind="reg");
# ```

# %%
sns.lmplot(
    data=tips,
    x='total_bill',
    y='tip'
)
